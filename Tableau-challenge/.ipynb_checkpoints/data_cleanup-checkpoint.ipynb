# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
citi_Jan19 = "Resources/JC-201901-citibike-tripdata.csv"
citi_Feb19 = "Resources/JC-201902-citibike-tripdata.csv"
citi_Mar19 = "Resources/JC-201903-citibike-tripdata.csv"
citi_Apr19 = "Resources/JC-201904-citibike-tripdata.csv"
citi_May19 = "Resources/JC-201905-citibike-tripdata.csv"
citi_Jun19 = "Resources/JC-201906-citibike-tripdata.csv"
citi_Jul19 = "Resources/JC-201907-citibike-tripdata.csv"
citi_Aug19 = "Resources/JC-201908-citibike-tripdata.csv"
citi_Sep19 = "Resources/JC-201909-citibike-tripdata.csv"
citi_Oct19 = "Resources/JC-201910-citibike-tripdata.csv"
citi_Nov19 = "Resources/JC-201911-citibike-tripdata.csv"
citi_Dec19 = "Resources/JC-201912-citibike-tripdata.csv"
citi_Jan20 = "Resources/JC-202001-citibike-tripdata.csv"
citi_Feb20 = "Resources/JC-202002-citibike-tripdata.csv"
citi_Mar20 = "Resources/JC-202003-citibike-tripdata.csv"
citi_Apr20 = "Resources/JC-202004-citibike-tripdata.csv"
citi_May20 = "Resources/JC-202005-citibike-tripdata.csv"
citi_Jun20 = "Resources/JC-202006-citibike-tripdata.csv"
citi_Jul20 = "Resources/JC-202007-citibike-tripdata.csv"
citi_Aug20 = "Resources/JC-202008-citibike-tripdata.csv"
citi_Sep20 = "Resources/JC-202009-citibike-tripdata.csv"
citi_Oct20 = "Resources/JC-202010-citibike-tripdata.csv"
citi_Nov20 = "Resources/JC-202011-citibike-tripdata.csv"
citi_Dec20 = "Resources/JC-202012-citibike-tripdata.csv"

# Read citibike and store into Pandas data frame
citi_0119 = pd.read_csv(citi_Jan19)
citi_0219 = pd.read_csv(citi_Feb19)
citi_0319 = pd.read_csv(citi_Mar19)
citi_0419 = pd.read_csv(citi_Apr19)
citi_0519 = pd.read_csv(citi_May19)
citi_0619 = pd.read_csv(citi_Jun19)
citi_0719 = pd.read_csv(citi_Jul19)
citi_0819 = pd.read_csv(citi_Aug19)
citi_0919 = pd.read_csv(citi_Sep19)
citi_1019 = pd.read_csv(citi_Oct19)
citi_1119 = pd.read_csv(citi_Nov19)
citi_1219 = pd.read_csv(citi_Dec19)
citi_0120 = pd.read_csv(citi_Jan20)
citi_0220 = pd.read_csv(citi_Feb20)
citi_0320 = pd.read_csv(citi_Mar20)
citi_0420 = pd.read_csv(citi_Apr20)
citi_0520 = pd.read_csv(citi_May20)
citi_0620 = pd.read_csv(citi_Jun20)
citi_0720 = pd.read_csv(citi_Jul20)
citi_0820 = pd.read_csv(citi_Aug20)
citi_0920 = pd.read_csv(citi_Sep20)
citi_1020 = pd.read_csv(citi_Oct20)
citi_1120 = pd.read_csv(citi_Nov20)
citi_1220 = pd.read_csv(citi_Dec20)

citi_1120.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           756  2020-11-01 00:11:32.6250  2020-11-01 00:24:09.5850
# 1           584  2020-11-01 00:14:20.4820  2020-11-01 00:24:04.7820
# 2           403  2020-11-01 00:22:55.8820  2020-11-01 00:29:39.0950
# 3           498  2020-11-01 00:41:37.4270  2020-11-01 00:49:55.7010
# 4           151  2020-11-01 00:53:21.2340  2020-11-01 00:55:52.8060
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3681           Grand St               40.715178
# 2              3203      Hamilton Park               40.727596
# 3              3268     Lafayette Park               40.713464
# 4              3185          City Hall               40.717733
#
#    start station longitude  end station id       end station name  \
# 0               -74.038914            3225  Baldwin at Montgomery
# ...
