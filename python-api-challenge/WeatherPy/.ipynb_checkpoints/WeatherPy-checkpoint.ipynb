# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\zanek\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\zanek\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\zanek\anaconda3\envs\pythondata\python.exe -m pip install --upgrade pip' command.

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from scipy.stats import linregress
#Pull in API and citipy
from api_keys import weather_api_key
from citipy import citipy

#Set the output file
output_file_csv = "../output_data/cities.csv"

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lng = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for coord in lat_lngs:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country.upper())

# Print the city count to confirm sufficient count
print(len(cities))

#Print the country count to confirm it matches city count
print(len(countries))
# Out:
# 587
# 587

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Create a dataframe to store the data
city_weather = pd.DataFrame({'City': cities, 'Cloudiness (%)': "", 'Country': countries, 'Date': "",
                            'Humidity (%)': "", 'Lat': "", 'Lng': "", 'Max Temp (F)': "", 'Windspeed (MPH)': ""})

#Preview the dataframe
city_weather.head()
# Out:
#           City Cloudiness (%) Country Date Humidity (%) Lat Lng Max Temp (F)  \
# 0       atuona                     PF
# 1        ndele                     CF
# 2  bolungarvik                     IS
# 3       dikson                     RU
# 4  new norfolk                     AU
#
#   Windspeed (MPH)
# 0
# 1
# 2
# 3
# 4

# %%
#Variables to keep track of response number
record_num = 1
record_set = 1

#Base url to make the api call
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&q='

#Run the API call for each city
print('''
-----------------------------
Beginning Data Retrieval
-----------------------------''')
for index, row in city_weather.iterrows(): 
    #Create the query url for the API call
    query_url = base_url + row['City'] + ',' + row['Country'] + '&APPID=' + weather_api_key
    
    #API call
    response = requests.get(query_url).json()
    
    #Exception script in case the city is not found by the API call
    try: 
        #Meassage to alert the user that the data is being retrieved
        print(f'Processing Weather Data for Record {record_num} of Set {record_set} | {response["name"]}')
        
        #Input data into the dataframe
        city_weather.loc[index, 'Cloudiness (%)'] = response['clouds']['all']
        city_weather.loc[index, 'Date'] = response['dt']
        city_weather.loc[index, 'Humidity (%)'] = response['main']['humidity']
        city_weather.loc[index, 'Lat'] = response['coord']['lat']
        city_weather.loc[index, 'Lng'] = response['coord']['lon']
        city_weather.loc[index, 'Max Temp (F)'] = response['main']['temp_max']
        city_weather.loc[index, 'Windspeed (MPH)'] = response['wind']['speed']
        
        #Increase the record count
        record_num += 1
        
    except (KeyError, IndexError):
        print("City not found....Skipping............")
    
    #If statement to handle the API call limits
    if record_num == 51:
        record_set += 1
        record_num = 1
        
print('''
-----------------------------
Data Retrival Complete
-----------------------------''')
# Out:
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Weather Data for Record 1 of Set 1 | Atuona
# Processing Weather Data for Record 2 of Set 1 | Ndélé
# Processing Weather Data for Record 3 of Set 1 | Dikson
# Processing Weather Data for Record 4 of Set 1 | New Norfolk
# Processing Weather Data for Record 5 of Set 1 | Bethel
# Processing Weather Data for Record 6 of Set 1 | Hobart
# Processing Weather Data for Record 7 of Set 1 | Fortuna
# Processing Weather Data for Record 8 of Set 1 | Victoria Point
# Processing Weather Data for Record 9 of Set 1 | Vila Franca do Campo
# Processing Weather Data for Record 10 of Set 1 | Puerto Ayora
# Processing Weather Data for Record 11 of Set 1 | Tilichiki
# Processing Weather Data for Record 12 of Set 1 | Arraial do Cabo
# Processing Weather Data for Record 13 of Set 1 | Vanimo
# Processing Weather Data for Record 14 of Set 1 | Georgetown
# Processing Weather Data for Record 15 of Set 1 | Tuktoyaktuk
# Processing Weather Data for Record 16 of Set 1 | Laramie
# Processing Weather Data for Record 17 of Set 1 | Tobol
# Processing Weather Data for Record 18 of Set 1 | Saint George
# Processing Weather Data for Record 19 of Set 1 | Barrow
# Processing Weather Data for Record 20 of Set 1 | Shaunavon
# Processing Weather Data for Record 21 of Set 1 | Jamestown
# Processing Weather Data for Record 22 of Set 1 | Soc Trang
# Processing Weather Data for Record 23 of Set 1 | Rikitea
# Processing Weather Data for Record 24 of Set 1 | Chumikan
# Processing Weather Data for Record 25 of Set 1 | Busselton
# Processing Weather Data for Record 26 of Set 1 | Sakakah
# Processing Weather Data for Record 27 of Set 1 | Bajil
# Processing Weather Data for Record 28 of Set 1 | Adrar
# Processing Weather Data for Record 29 of Set 1 | Opuwo
# Processing Weather Data for Record 30 of Set 1 | Mareeba
# Processing Weather Data for Record 31 of Set 1 | Lorengau
# Processing Weather Data for Record 32 of Set 1 | Qaanaaq
# Processing Weather Data for Record 33 of Set 1 | Ahipara
# Processing Weather Data for Record 34 of Set 1 | Port Alfred
# Processing Weather Data for Record 35 of Set 1 | Ushuaia
# Processing Weather Data for Record 36 of Set 1 | Zimovniki
# Processing Weather Data for Record 37 of Set 1 | Umba
# Processing Weather Data for Record 38 of Set 1 | Mayya
# Processing Weather Data for Record 39 of Set 1 | Krasnovishersk
# Processing Weather Data for Record 40 of Set 1 | Albany
# Processing Weather Data for Record 41 of Set 1 | Kapaa
# Processing Weather Data for Record 42 of Set 1 | Sola
# Processing Weather Data for Record 43 of Set 1 | Ossora
# Processing Weather Data for Record 44 of Set 1 | São Filipe
# Processing Weather Data for Record 45 of Set 1 | Klaksvík
# Processing Weather Data for Record 46 of Set 1 | Coahuayana Viejo
# Processing Weather Data for Record 47 of Set 1 | Constitucion
# Processing Weather Data for Record 48 of Set 1 | Avarua
# Processing Weather Data for Record 49 of Set 1 | Port Elizabeth
# Processing Weather Data for Record 50 of Set 1 | Vidim
# Processing Weather Data for Record 1 of Set 2 | Porto Novo
# Processing Weather Data for Record 2 of Set 2 | Tuatapere
# Processing Weather Data for Record 3 of Set 2 | Hermanus
# Processing Weather Data for Record 4 of Set 2 | Vaini
# Processing Weather Data for Record 5 of Set 2 | Sakaiminato
# Processing Weather Data for Record 6 of Set 2 | Queimadas
# Processing Weather Data for Record 7 of Set 2 | Avilés
# Processing Weather Data for Record 8 of Set 2 | Hofn
# Processing Weather Data for Record 9 of Set 2 | Hambantota
# Processing Weather Data for Record 10 of Set 2 | East London
# Processing Weather Data for Record 11 of Set 2 | Nanortalik
# Processing Weather Data for Record 12 of Set 2 | Butaritari
# Processing Weather Data for Record 13 of Set 2 | Bluff
# Processing Weather Data for Record 14 of Set 2 | Nikolskoye
# Processing Weather Data for Record 15 of Set 2 | Solnechnyy
# Processing Weather Data for Record 16 of Set 2 | Kantunilkín
# Processing Weather Data for Record 17 of Set 2 | Beringovskiy
# Processing Weather Data for Record 18 of Set 2 | Bonavista
# Processing Weather Data for Record 19 of Set 2 | Paamiut
# Processing Weather Data for Record 20 of Set 2 | Jardim
# Processing Weather Data for Record 21 of Set 2 | Souillac
# Processing Weather Data for Record 22 of Set 2 | Esperance
# Processing Weather Data for Record 23 of Set 2 | Scarborough
# Processing Weather Data for Record 24 of Set 2 | Punta Arenas
# Processing Weather Data for Record 25 of Set 2 | Kodinsk
# Processing Weather Data for Record 26 of Set 2 | Saint-Philippe
# Processing Weather Data for Record 27 of Set 2 | Ambon City
# Processing Weather Data for Record 28 of Set 2 | Loreto
# Processing Weather Data for Record 29 of Set 2 | Palora
# Processing Weather Data for Record 30 of Set 2 | Yellowknife
# Processing Weather Data for Record 31 of Set 2 | Columbus
# Processing Weather Data for Record 32 of Set 2 | Tarakan
# Processing Weather Data for Record 33 of Set 2 | Menongue
# Processing Weather Data for Record 34 of Set 2 | Mar del Plata
# Processing Weather Data for Record 35 of Set 2 | Bambanglipuro
# Processing Weather Data for Record 36 of Set 2 | Yenagoa
# Processing Weather Data for Record 37 of Set 2 | Praya
# Processing Weather Data for Record 38 of Set 2 | Santa Cruz
# Processing Weather Data for Record 39 of Set 2 | Norman Wells
# Processing Weather Data for Record 40 of Set 2 | Chvaletice
# Processing Weather Data for Record 41 of Set 2 | Marsá Maţrūḩ
# Processing Weather Data for Record 42 of Set 2 | Bintulu
# Processing Weather Data for Record 43 of Set 2 | Mazagão
# Processing Weather Data for Record 44 of Set 2 | Juradó
# Processing Weather Data for Record 45 of Set 2 | Geraldton
# Processing Weather Data for Record 46 of Set 2 | Mackenzie
# Processing Weather Data for Record 47 of Set 2 | Padang
# Processing Weather Data for Record 48 of Set 2 | Cherskiy
# Processing Weather Data for Record 49 of Set 2 | Tres Arroyos
# Processing Weather Data for Record 50 of Set 2 | Carnarvon
# Processing Weather Data for Record 1 of Set 3 | Rosário Oeste
# Processing Weather Data for Record 2 of Set 3 | Olinda
# Processing Weather Data for Record 3 of Set 3 | Bredasdorp
# Processing Weather Data for Record 4 of Set 3 | Zherdevka
# Processing Weather Data for Record 5 of Set 3 | Zheleznodorozhnyy
# Processing Weather Data for Record 6 of Set 3 | Mount Gambier
# Processing Weather Data for Record 7 of Set 3 | Tataouine
# Processing Weather Data for Record 8 of Set 3 | Cilegon
# Processing Weather Data for Record 9 of Set 3 | Clyde River
# Processing Weather Data for Record 10 of Set 3 | Port-Gentil
# Processing Weather Data for Record 11 of Set 3 | São José do Belmonte
# Processing Weather Data for Record 12 of Set 3 | Ribeira Grande
# Processing Weather Data for Record 13 of Set 3 | Nouakchott
# Processing Weather Data for Record 14 of Set 3 | Dunedin
# Processing Weather Data for Record 15 of Set 3 | Ranong
# Processing Weather Data for Record 16 of Set 3 | Severo-Kuril'sk
# Processing Weather Data for Record 17 of Set 3 | Quryq
# Processing Weather Data for Record 18 of Set 3 | Qaqortoq
# Processing Weather Data for Record 19 of Set 3 | Cape Town
# Processing Weather Data for Record 20 of Set 3 | Eureka
# Processing Weather Data for Record 21 of Set 3 | Hithadhoo
# Processing Weather Data for Record 22 of Set 3 | Lüderitz
# Processing Weather Data for Record 23 of Set 3 | Pilar
# Processing Weather Data for Record 24 of Set 3 | Puerto Escondido
# Processing Weather Data for Record 25 of Set 3 | Dao
# Processing Weather Data for Record 26 of Set 3 | Eston
# Processing Weather Data for Record 27 of Set 3 | Lebu
# Processing Weather Data for Record 28 of Set 3 | Hilo
# Processing Weather Data for Record 29 of Set 3 | Vao
# Processing Weather Data for Record 30 of Set 3 | Dorado
# Processing Weather Data for Record 31 of Set 3 | Talnakh
# Processing Weather Data for Record 32 of Set 3 | Bambous Virieux
# Processing Weather Data for Record 33 of Set 3 | Angoche
# Processing Weather Data for Record 34 of Set 3 | Pringsewu
# Processing Weather Data for Record 35 of Set 3 | Kloulklubed
# Processing Weather Data for Record 36 of Set 3 | Talisay City
# Processing Weather Data for Record 37 of Set 3 | Luwuk
# Processing Weather Data for Record 38 of Set 3 | Sheregesh
# Processing Weather Data for Record 39 of Set 3 | Izberbash
# Processing Weather Data for Record 40 of Set 3 | Kruisfontein
# Processing Weather Data for Record 41 of Set 3 | Ilulissat
# Processing Weather Data for Record 42 of Set 3 | Viana
# Processing Weather Data for Record 43 of Set 3 | Inta
# Processing Weather Data for Record 44 of Set 3 | Belmonte
# Processing Weather Data for Record 45 of Set 3 | Lake Shasta
# Processing Weather Data for Record 46 of Set 3 | Thinadhoo
# Processing Weather Data for Record 47 of Set 3 | Guerrero Negro
# Processing Weather Data for Record 48 of Set 3 | Abasolo
# Processing Weather Data for Record 49 of Set 3 | Thompson
# Processing Weather Data for Record 50 of Set 3 | Inhambane
# Processing Weather Data for Record 1 of Set 4 | Dobruševo
# Processing Weather Data for Record 2 of Set 4 | Sovetskiy
# Processing Weather Data for Record 3 of Set 4 | Camopi
# Processing Weather Data for Record 4 of Set 4 | Berdigestyakh
# Processing Weather Data for Record 5 of Set 4 | Quepos
# Processing Weather Data for Record 6 of Set 4 | Muros
# Processing Weather Data for Record 7 of Set 4 | Khatanga
# Processing Weather Data for Record 8 of Set 4 | Grand Gaube
# Processing Weather Data for Record 9 of Set 4 | Atar
# Processing Weather Data for Record 10 of Set 4 | Boyuibe
# Processing Weather Data for Record 11 of Set 4 | Caravelas
# Processing Weather Data for Record 12 of Set 4 | Narón
# Processing Weather Data for Record 13 of Set 4 | Karratha
# Processing Weather Data for Record 14 of Set 4 | Mossendjo
# Processing Weather Data for Record 15 of Set 4 | Sambava
# Processing Weather Data for Record 16 of Set 4 | Chipiona
# Processing Weather Data for Record 17 of Set 4 | Ternate
# Processing Weather Data for Record 18 of Set 4 | Mahébourg
# Processing Weather Data for Record 19 of Set 4 | Jiwani
# Processing Weather Data for Record 20 of Set 4 | Longyearbyen
# Processing Weather Data for Record 21 of Set 4 | Faanui
# Processing Weather Data for Record 22 of Set 4 | Hagerstown
# Processing Weather Data for Record 23 of Set 4 | Castro
# Processing Weather Data for Record 24 of Set 4 | Hualmay
# Processing Weather Data for Record 25 of Set 4 | Haapsalu
# Processing Weather Data for Record 26 of Set 4 | Westport
# Processing Weather Data for Record 27 of Set 4 | Marshall
# Processing Weather Data for Record 28 of Set 4 | Ulladulla
# Processing Weather Data for Record 29 of Set 4 | Batemans Bay
# Processing Weather Data for Record 30 of Set 4 | Hobyo
# Processing Weather Data for Record 31 of Set 4 | Katsuura
# Processing Weather Data for Record 32 of Set 4 | Victoria
# Processing Weather Data for Record 33 of Set 4 | Tutayev
# Processing Weather Data for Record 34 of Set 4 | Luís Correia
# Processing Weather Data for Record 35 of Set 4 | Wangqing
# Processing Weather Data for Record 36 of Set 4 | Dicabisagan
# Processing Weather Data for Record 37 of Set 4 | Coquimbo
# Processing Weather Data for Record 38 of Set 4 | Knysna
# Processing Weather Data for Record 39 of Set 4 | Iwanai
# Processing Weather Data for Record 40 of Set 4 | Tasiilaq
# Processing Weather Data for Record 41 of Set 4 | Valley
# Processing Weather Data for Record 42 of Set 4 | Nyurba
# Processing Weather Data for Record 43 of Set 4 | Krasnosel'kup
# Processing Weather Data for Record 44 of Set 4 | Morondava
# Processing Weather Data for Record 45 of Set 4 | Jijiga
# Processing Weather Data for Record 46 of Set 4 | Pangkalanbuun
# Processing Weather Data for Record 47 of Set 4 | Salihorsk
# Processing Weather Data for Record 48 of Set 4 | Måløy
# Processing Weather Data for Record 49 of Set 4 | Port Blair
# Processing Weather Data for Record 50 of Set 4 | Vila Velha
# Processing Weather Data for Record 1 of Set 5 | Amapá
# Processing Weather Data for Record 2 of Set 5 | Isangel
# Processing Weather Data for Record 3 of Set 5 | Labytnangi
# Processing Weather Data for Record 4 of Set 5 | Pisco
# Processing Weather Data for Record 5 of Set 5 | Dubbo
# Processing Weather Data for Record 6 of Set 5 | Touros
# Processing Weather Data for Record 7 of Set 5 | Bengkulu
# Processing Weather Data for Record 8 of Set 5 | Senanga
# Processing Weather Data for Record 9 of Set 5 | Davila
# Processing Weather Data for Record 10 of Set 5 | Sonqor
# Processing Weather Data for Record 11 of Set 5 | Suez
# Processing Weather Data for Record 12 of Set 5 | Kulebaki
# Processing Weather Data for Record 13 of Set 5 | Evensk
# Processing Weather Data for Record 14 of Set 5 | Labuhan
# Processing Weather Data for Record 15 of Set 5 | Pangnirtung
# Processing Weather Data for Record 16 of Set 5 | Pevek
# Processing Weather Data for Record 17 of Set 5 | Anadyr
# Processing Weather Data for Record 18 of Set 5 | Bānswāra
# Processing Weather Data for Record 19 of Set 5 | Marabu
# Processing Weather Data for Record 20 of Set 5 | Kabo
# Processing Weather Data for Record 21 of Set 5 | Ballina
# Processing Weather Data for Record 22 of Set 5 | Bratsk
# Processing Weather Data for Record 23 of Set 5 | Lompoc
# Processing Weather Data for Record 24 of Set 5 | Yar-Sale
# Processing Weather Data for Record 25 of Set 5 | Huangpi
# Processing Weather Data for Record 26 of Set 5 | Abu Dhabi
# Processing Weather Data for Record 27 of Set 5 | Cabo San Lucas
# Processing Weather Data for Record 28 of Set 5 | Olafsvik
# Processing Weather Data for Record 29 of Set 5 | Upernavik
# Processing Weather Data for Record 30 of Set 5 | Kaitangata
# Processing Weather Data for Record 31 of Set 5 | Chimoré
# Processing Weather Data for Record 32 of Set 5 | Provideniya
# Processing Weather Data for Record 33 of Set 5 | Havre-St-Pierre
# Processing Weather Data for Record 34 of Set 5 | Hasaki
# Processing Weather Data for Record 35 of Set 5 | Bāsār
# Processing Weather Data for Record 36 of Set 5 | Ostrovnoy
# Processing Weather Data for Record 37 of Set 5 | Flinders
# Processing Weather Data for Record 38 of Set 5 | Loandjili
# Processing Weather Data for Record 39 of Set 5 | Acapulco de Juárez
# Processing Weather Data for Record 40 of Set 5 | Oktyabr'skiy
# Processing Weather Data for Record 41 of Set 5 | Shache
# Processing Weather Data for Record 42 of Set 5 | Pacific Grove
# Processing Weather Data for Record 43 of Set 5 | Harindānga
# Processing Weather Data for Record 44 of Set 5 | Santa Cruz de La Palma
# Processing Weather Data for Record 45 of Set 5 | Bantry
# Processing Weather Data for Record 46 of Set 5 | Tessalit
# Processing Weather Data for Record 47 of Set 5 | Caribou
# Processing Weather Data for Record 48 of Set 5 | Narsaq
# Processing Weather Data for Record 49 of Set 5 | Port Hedland
# Processing Weather Data for Record 50 of Set 5 | Kaeo
# Processing Weather Data for Record 1 of Set 6 | Manyana
# Processing Weather Data for Record 2 of Set 6 | Mörön
# Processing Weather Data for Record 3 of Set 6 | Bathsheba
# Processing Weather Data for Record 4 of Set 6 | Matonga
# Processing Weather Data for Record 5 of Set 6 | San Patricio
# Processing Weather Data for Record 6 of Set 6 | Daru
# Processing Weather Data for Record 7 of Set 6 | Tura
# Processing Weather Data for Record 8 of Set 6 | Longyan
# Processing Weather Data for Record 9 of Set 6 | Horadiz
# Processing Weather Data for Record 10 of Set 6 | Poum
# Processing Weather Data for Record 11 of Set 6 | Prince Rupert
# Processing Weather Data for Record 12 of Set 6 | Lamar
# Processing Weather Data for Record 13 of Set 6 | Powell River
# Processing Weather Data for Record 14 of Set 6 | Kalianget
# Processing Weather Data for Record 15 of Set 6 | Kabanjahe
# Processing Weather Data for Record 16 of Set 6 | Vilhena
# Processing Weather Data for Record 17 of Set 6 | San Quintín
# Processing Weather Data for Record 18 of Set 6 | Batticaloa
# Processing Weather Data for Record 19 of Set 6 | Chokurdakh
# Processing Weather Data for Record 20 of Set 6 | Ancud
# Processing Weather Data for Record 21 of Set 6 | Chui
# Processing Weather Data for Record 22 of Set 6 | Ucluelet
# Processing Weather Data for Record 23 of Set 6 | Ingrāj Bāzār
# Processing Weather Data for Record 24 of Set 6 | Cayenne
# Processing Weather Data for Record 25 of Set 6 | Vabalninkas
# Processing Weather Data for Record 26 of Set 6 | Tiksi
# Processing Weather Data for Record 27 of Set 6 | Phalombe
# Processing Weather Data for Record 28 of Set 6 | Mponela
# Processing Weather Data for Record 29 of Set 6 | Kumbo
# Processing Weather Data for Record 30 of Set 6 | Ismailia
# Processing Weather Data for Record 31 of Set 6 | Gimli
# Processing Weather Data for Record 32 of Set 6 | Chifeng
# Processing Weather Data for Record 33 of Set 6 | Vestmanna
# Processing Weather Data for Record 34 of Set 6 | Marau
# Processing Weather Data for Record 35 of Set 6 | Salisbury
# Processing Weather Data for Record 36 of Set 6 | Pueblo Nuevo
# Processing Weather Data for Record 37 of Set 6 | Washington
# Processing Weather Data for Record 38 of Set 6 | Sisimiut
# Processing Weather Data for Record 39 of Set 6 | Kahului
# Processing Weather Data for Record 40 of Set 6 | Lábrea
# Processing Weather Data for Record 41 of Set 6 | Caimito
# Processing Weather Data for Record 42 of Set 6 | Namtsy
# Processing Weather Data for Record 43 of Set 6 | Mossamedes
# Processing Weather Data for Record 44 of Set 6 | Meulaboh
# Processing Weather Data for Record 45 of Set 6 | Sinnamary
# Processing Weather Data for Record 46 of Set 6 | Samsun Province
# Processing Weather Data for Record 47 of Set 6 | Oranjemund
# Processing Weather Data for Record 48 of Set 6 | Santoña
# Processing Weather Data for Record 49 of Set 6 | Arinos
# Processing Weather Data for Record 50 of Set 6 | Ixtapa
# Processing Weather Data for Record 1 of Set 7 | Macaúbas
# Processing Weather Data for Record 2 of Set 7 | Utrecht
# Processing Weather Data for Record 3 of Set 7 | Santa Fe
# Processing Weather Data for Record 4 of Set 7 | Bon Accord
# Processing Weather Data for Record 5 of Set 7 | Rocha
# Processing Weather Data for Record 6 of Set 7 | Itapetinga
# Processing Weather Data for Record 7 of Set 7 | Yumen
# Processing Weather Data for Record 8 of Set 7 | Staroutkinsk
# Processing Weather Data for Record 9 of Set 7 | Malia
# Processing Weather Data for Record 10 of Set 7 | Beloha
# Processing Weather Data for Record 11 of Set 7 | Esmeraldas
# Processing Weather Data for Record 12 of Set 7 | Okulovka
# Processing Weather Data for Record 13 of Set 7 | Ponta Delgada
# Processing Weather Data for Record 14 of Set 7 | Cockburn Town
# Processing Weather Data for Record 15 of Set 7 | Vestmannaeyjar
# Processing Weather Data for Record 16 of Set 7 | Kavaratti
# Processing Weather Data for Record 17 of Set 7 | Kangaatsiaq
# Processing Weather Data for Record 18 of Set 7 | Port Hardy
# Processing Weather Data for Record 19 of Set 7 | Tornio
# Processing Weather Data for Record 20 of Set 7 | Lékoni
# Processing Weather Data for Record 21 of Set 7 | Sabang
# Processing Weather Data for Record 22 of Set 7 | Port Macquarie
# Processing Weather Data for Record 23 of Set 7 | Alenquer
# Processing Weather Data for Record 24 of Set 7 | Prado
# Processing Weather Data for Record 25 of Set 7 | Lusaka
# Processing Weather Data for Record 26 of Set 7 | Tūkrah
# Processing Weather Data for Record 27 of Set 7 | Kavieng
# Processing Weather Data for Record 28 of Set 7 | Pallasovka
# Processing Weather Data for Record 29 of Set 7 | Grindavik
# Processing Weather Data for Record 30 of Set 7 | North Bend
# Processing Weather Data for Record 31 of Set 7 | Tautira
# Processing Weather Data for Record 32 of Set 7 | Bucerías
# Processing Weather Data for Record 33 of Set 7 | Santa Isabel Rio Negro
# Processing Weather Data for Record 34 of Set 7 | Rawson
# Processing Weather Data for Record 35 of Set 7 | Lavrentiya
# Processing Weather Data for Record 36 of Set 7 | Saskylakh
# Processing Weather Data for Record 37 of Set 7 | Iqaluit
# Processing Weather Data for Record 38 of Set 7 | Saint Paul Harbor
# Processing Weather Data for Record 39 of Set 7 | Salinópolis
# Processing Weather Data for Record 40 of Set 7 | Nagato
# Processing Weather Data for Record 41 of Set 7 | Komsomol'skiy
# Processing Weather Data for Record 42 of Set 7 | Vuktyl
# Processing Weather Data for Record 43 of Set 7 | Oussouye
# Processing Weather Data for Record 44 of Set 7 | Naze
# Processing Weather Data for Record 45 of Set 7 | Jiazi
# Processing Weather Data for Record 46 of Set 7 | Taltal
# Processing Weather Data for Record 47 of Set 7 | Mahibadhoo
# Processing Weather Data for Record 48 of Set 7 | Garissa
# Processing Weather Data for Record 49 of Set 7 | São Miguel do Araguaia
# Processing Weather Data for Record 50 of Set 7 | Uyuni
# Processing Weather Data for Record 1 of Set 8 | Gornyak
# Processing Weather Data for Record 2 of Set 8 | Yulara
# Processing Weather Data for Record 3 of Set 8 | Sitrah
# Processing Weather Data for Record 4 of Set 8 | Mount Isa
# Processing Weather Data for Record 5 of Set 8 | Kupang
# Processing Weather Data for Record 6 of Set 8 | Tshikapa
# Processing Weather Data for Record 7 of Set 8 | Mahajanga
# Processing Weather Data for Record 8 of Set 8 | Yantal'
# Processing Weather Data for Record 9 of Set 8 | Natal
# Processing Weather Data for Record 10 of Set 8 | Elban
# Processing Weather Data for Record 11 of Set 8 | Berestechko
# Processing Weather Data for Record 12 of Set 8 | Kashan
# Processing Weather Data for Record 13 of Set 8 | Deputatsky
# Processing Weather Data for Record 14 of Set 8 | Berbérati
# Processing Weather Data for Record 15 of Set 8 | Punta Alta
# Processing Weather Data for Record 16 of Set 8 | Sur
# Processing Weather Data for Record 17 of Set 8 | Crossville
# Processing Weather Data for Record 18 of Set 8 | Berlevåg
# Processing Weather Data for Record 19 of Set 8 | Moose Factory
# Processing Weather Data for Record 20 of Set 8 | Sabha
# Processing Weather Data for Record 21 of Set 8 | Martapura
# Processing Weather Data for Record 22 of Set 8 | Bereket
# Processing Weather Data for Record 23 of Set 8 | Torbay
# Processing Weather Data for Record 24 of Set 8 | Ayabaca
# Processing Weather Data for Record 25 of Set 8 | Nurota
# Processing Weather Data for Record 26 of Set 8 | Tahoua
# Processing Weather Data for Record 27 of Set 8 | Koceljeva
# Processing Weather Data for Record 28 of Set 8 | Tumaco
# Processing Weather Data for Record 29 of Set 8 | Christiana
# Processing Weather Data for Record 30 of Set 8 | Saint-Ambroise
# Processing Weather Data for Record 31 of Set 8 | Makakilo City
# Processing Weather Data for Record 32 of Set 8 | Jiangyou
# Processing Weather Data for Record 33 of Set 8 | Ponta do Sol
# Processing Weather Data for Record 34 of Set 8 | Roma
# Processing Weather Data for Record 35 of Set 8 | Artyshta
# Processing Weather Data for Record 36 of Set 8 | Santo Domingo de los Colorados
# Processing Weather Data for Record 37 of Set 8 | Igarka
# Processing Weather Data for Record 38 of Set 8 | Qasigiannguit
# Processing Weather Data for Record 39 of Set 8 | Nome
# Processing Weather Data for Record 40 of Set 8 | Borova
# Processing Weather Data for Record 41 of Set 8 | Ryōtsu-minato
# Processing Weather Data for Record 42 of Set 8 | Luganville
# Processing Weather Data for Record 43 of Set 8 | São José da Coroa Grande
# Processing Weather Data for Record 44 of Set 8 | Chichester
# Processing Weather Data for Record 45 of Set 8 | Saint Albans
# Processing Weather Data for Record 46 of Set 8 | Maltahöhe
# Processing Weather Data for Record 47 of Set 8 | Akureyri
# Processing Weather Data for Record 48 of Set 8 | Yining
# Processing Weather Data for Record 49 of Set 8 | Gizo Government Station
# Processing Weather Data for Record 50 of Set 8 | Port Lincoln
# Processing Weather Data for Record 1 of Set 9 | Basco
# Processing Weather Data for Record 2 of Set 9 | Margate
# Processing Weather Data for Record 3 of Set 9 | Salym
# Processing Weather Data for Record 4 of Set 9 | Mahon
# Processing Weather Data for Record 5 of Set 9 | Sidney
# Processing Weather Data for Record 6 of Set 9 | Poplar Bluff
# Processing Weather Data for Record 7 of Set 9 | Sibi
# Processing Weather Data for Record 8 of Set 9 | Bilibino
# Processing Weather Data for Record 9 of Set 9 | Manokwari
# Processing Weather Data for Record 10 of Set 9 | Tynda
# Processing Weather Data for Record 11 of Set 9 | Montluçon
# Processing Weather Data for Record 12 of Set 9 | Halifax
# Processing Weather Data for Record 13 of Set 9 | Nouadhibou
# Processing Weather Data for Record 14 of Set 9 | Saldanha
# Processing Weather Data for Record 15 of Set 9 | Chornobay
# Processing Weather Data for Record 16 of Set 9 | Khawhai
# Processing Weather Data for Record 17 of Set 9 | Khandyga
# Processing Weather Data for Record 18 of Set 9 | Heraclea
# Processing Weather Data for Record 19 of Set 9 | Gornopravdinsk
# Processing Weather Data for Record 20 of Set 9 | Alice Springs
# Processing Weather Data for Record 21 of Set 9 | Sibolga
# Processing Weather Data for Record 22 of Set 9 | Chlórakas
# Processing Weather Data for Record 23 of Set 9 | Waterloo
# Processing Weather Data for Record 24 of Set 9 | Weyburn
# Processing Weather Data for Record 25 of Set 9 | Peleduy
# Processing Weather Data for Record 26 of Set 9 | Missoula
# Processing Weather Data for Record 27 of Set 9 | Portland
# Processing Weather Data for Record 28 of Set 9 | Dogondoutchi
# Processing Weather Data for Record 29 of Set 9 | Béboto
# Processing Weather Data for Record 30 of Set 9 | Namatanai
# Processing Weather Data for Record 31 of Set 9 | Muisne
# Processing Weather Data for Record 32 of Set 9 | Pokhara
# Processing Weather Data for Record 33 of Set 9 | Two Rivers
# Processing Weather Data for Record 34 of Set 9 | Atyashevo
# Processing Weather Data for Record 35 of Set 9 | Urengoy
# Processing Weather Data for Record 36 of Set 9 | Markova
# Processing Weather Data for Record 37 of Set 9 | Jinchang
# Processing Weather Data for Record 38 of Set 9 | Chicama
# Processing Weather Data for Record 39 of Set 9 | Øksfjord
# Processing Weather Data for Record 40 of Set 9 | Barabai
# Processing Weather Data for Record 41 of Set 9 | Linxia Chengguanzhen
# Processing Weather Data for Record 42 of Set 9 | Logan
# Processing Weather Data for Record 43 of Set 9 | Chieri
# Processing Weather Data for Record 44 of Set 9 | Ugoofaaru
# Processing Weather Data for Record 45 of Set 9 | Skovorodino
# Processing Weather Data for Record 46 of Set 9 | Pasco
# Processing Weather Data for Record 47 of Set 9 | College
# Processing Weather Data for Record 48 of Set 9 | Meridian
# Processing Weather Data for Record 49 of Set 9 | Ilebo
# Processing Weather Data for Record 50 of Set 9 | Izhma
# Processing Weather Data for Record 1 of Set 10 | Akdepe
# Processing Weather Data for Record 2 of Set 10 | Skeldon
# Processing Weather Data for Record 3 of Set 10 | Aguada de Pasajeros
# Processing Weather Data for Record 4 of Set 10 | Puerto Carreño
# Processing Weather Data for Record 5 of Set 10 | Vidalia
# Processing Weather Data for Record 6 of Set 10 | Kovdor
# Processing Weather Data for Record 7 of Set 10 | Davidson
# Processing Weather Data for Record 8 of Set 10 | Dnestrovsc
# Processing Weather Data for Record 9 of Set 10 | Trelew
# Processing Weather Data for Record 10 of Set 10 | Norton Shores
# Processing Weather Data for Record 11 of Set 10 | Mahabalipuram
# Processing Weather Data for Record 12 of Set 10 | Barra do Garças
# Processing Weather Data for Record 13 of Set 10 | San Vicente
# Processing Weather Data for Record 14 of Set 10 | Shitanjing
# Processing Weather Data for Record 15 of Set 10 | Batangafo
# Processing Weather Data for Record 16 of Set 10 | Sitka
# Processing Weather Data for Record 17 of Set 10 | Rehoboth
# Processing Weather Data for Record 18 of Set 10 | Hammerfest
# Processing Weather Data for Record 19 of Set 10 | North Ogden
# Processing Weather Data for Record 20 of Set 10 | Grand Forks
# Processing Weather Data for Record 21 of Set 10 | Narasannapeta
# Processing Weather Data for Record 22 of Set 10 | Lagoa
# Processing Weather Data for Record 23 of Set 10 | Russell
# Processing Weather Data for Record 24 of Set 10 | Yelizovo
# Processing Weather Data for Record 25 of Set 10 | Am Timan
# Processing Weather Data for Record 26 of Set 10 | Florestópolis
# Processing Weather Data for Record 27 of Set 10 | Wilmington
# Processing Weather Data for Record 28 of Set 10 | Koltubanovskiy
# Processing Weather Data for Record 29 of Set 10 | Locri
# Processing Weather Data for Record 30 of Set 10 | Micheweni
# Processing Weather Data for Record 31 of Set 10 | Kichera
# Processing Weather Data for Record 32 of Set 10 | Bonthe
# Processing Weather Data for Record 33 of Set 10 | Trairi
# Processing Weather Data for Record 34 of Set 10 | Jalu
# Processing Weather Data for Record 35 of Set 10 | Baruun-Urt
# Processing Weather Data for Record 36 of Set 10 | Teahupoo
# Processing Weather Data for Record 37 of Set 10 | Sharon
# Processing Weather Data for Record 38 of Set 10 | Arlit
# Processing Weather Data for Record 39 of Set 10 | Beruwala
# Processing Weather Data for Record 40 of Set 10 | Pozo Colorado
# Processing Weather Data for Record 41 of Set 10 | Verkhnyaya Inta
# Processing Weather Data for Record 42 of Set 10 | Mława
# Processing Weather Data for Record 43 of Set 10 | Inuvik
# Processing Weather Data for Record 44 of Set 10 | Xam Nua
# Processing Weather Data for Record 45 of Set 10 | Kokopo
# Processing Weather Data for Record 46 of Set 10 | Snyder
# Processing Weather Data for Record 47 of Set 10 | Zyryanka
# Processing Weather Data for Record 48 of Set 10 | Nichinan
# Processing Weather Data for Record 49 of Set 10 | Grand-Lahou
# Processing Weather Data for Record 50 of Set 10 | Dingli
# Processing Weather Data for Record 1 of Set 11 | Mackay
# Processing Weather Data for Record 2 of Set 11 | Egvekinot
# Processing Weather Data for Record 3 of Set 11 | Atbasar
# Processing Weather Data for Record 4 of Set 11 | Brae
# Processing Weather Data for Record 5 of Set 11 | Dutlwe
# Processing Weather Data for Record 6 of Set 11 | Tiarei
# Processing Weather Data for Record 7 of Set 11 | Tahe
# Processing Weather Data for Record 8 of Set 11 | Akhtanizovskaya
# Processing Weather Data for Record 9 of Set 11 | Salalah
# Processing Weather Data for Record 10 of Set 11 | Visnes
# Processing Weather Data for Record 11 of Set 11 | Auki
# Processing Weather Data for Record 12 of Set 11 | Nelson Bay
# Processing Weather Data for Record 13 of Set 11 | Bilma
# Processing Weather Data for Record 14 of Set 11 | Urubichá
# Processing Weather Data for Record 15 of Set 11 | Nizhniy Lomov
# Processing Weather Data for Record 16 of Set 11 | Puro
# Processing Weather Data for Record 17 of Set 11 | Ottawa
# Processing Weather Data for Record 18 of Set 11 | Chernyshevskiy
# Processing Weather Data for Record 19 of Set 11 | Soe
# Processing Weather Data for Record 20 of Set 11 | Turka
# Processing Weather Data for Record 21 of Set 11 | Alofi
# Processing Weather Data for Record 22 of Set 11 | Laguna
# Processing Weather Data for Record 23 of Set 11 | Oodweyne
# Processing Weather Data for Record 24 of Set 11 | Bam
# Processing Weather Data for Record 25 of Set 11 | Río Gallegos
# Processing Weather Data for Record 26 of Set 11 | Volot
# Processing Weather Data for Record 27 of Set 11 | Teya
# Processing Weather Data for Record 28 of Set 11 | Kafue
# Processing Weather Data for Record 29 of Set 11 | Bowen
# Processing Weather Data for Record 30 of Set 11 | Mabaruma
# Processing Weather Data for Record 31 of Set 11 | Sidi Ali
# Processing Weather Data for Record 32 of Set 11 | Nuoro
# Processing Weather Data for Record 33 of Set 11 | Homestead
# Processing Weather Data for Record 34 of Set 11 | Kirakira
#
# -----------------------------
# Data Retrival Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather.head()
# Out:
#           City Cloudiness (%) Country        Date Humidity (%)    Lat     Lng  \
# 0       atuona              3      PF  1603342249           74   -9.8 -139.03
# 1        ndele             94      CF  1603341837           81   8.41   20.65
# 3       dikson             99      RU  1603342265           96  73.51   80.55
# 4  new norfolk             75      AU  1603342265           59 -42.78  147.06
# 5       bethel             90      US  1603342265          100  41.37  -73.41
#
#    Max Temp (F) Windspeed (MPH)  Latitude  Longitude
# 0         77.92           15.55     -9.80    -139.03
# 1         70.20            2.89      8.41      20.65
# 3         25.50           11.99     73.51      80.55
# 4         61.00            9.17    -42.78     147.06
# 5         64.99            2.95     41.37     -73.41

# %%
#Clean dataframe to remove cities that were not found
city_weather['Max Temp (F)'] = city_weather['Max Temp (F)'].replace('', np.nan)
city_weather = city_weather.dropna()

# Convert data strings to float
pd.to_numeric(city_weather["Cloudiness (%)"]).astype(float)
pd.to_numeric(city_weather["Humidity (%)"]).astype(float)
pd.to_numeric(city_weather["Latitude"]).astype(float)
pd.to_numeric(city_weather["Longitude"]).astype(float)
pd.to_numeric(city_weather["Max Temp (F)"]).astype(float)
pd.to_numeric(city_weather["Windspeed (MPH)"]).astype(float)
city_weather['Date'] =  pd.to_datetime(city_weather['Date'])

#Save dataframe
city_weather.to_csv("../output_data/CityWeatherData.csv", index=False, header=True)

#Preview the dataframe
city_weather.head()
# Out:
#           City Cloudiness (%) Country                          Date  \
# 0       atuona              3      PF 1970-01-01 00:00:01.603342249
# 1        ndele             94      CF 1970-01-01 00:00:01.603341837
# 3       dikson             99      RU 1970-01-01 00:00:01.603342265
# 4  new norfolk             75      AU 1970-01-01 00:00:01.603342265
# 5       bethel             90      US 1970-01-01 00:00:01.603342265
#
#   Humidity (%)    Lat     Lng  Max Temp (F) Windspeed (MPH)  Latitude  \
# 0           74   -9.8 -139.03         77.92           15.55     -9.80
# 1           81   8.41   20.65         70.20            2.89      8.41
# 3           96  73.51   80.55         25.50           11.99     73.51
# 4           59 -42.78  147.06         61.00            9.17    -42.78
# 5          100  41.37  -73.41         64.99            2.95     41.37
#
#    Longitude
# 0    -139.03
# 1      20.65
# 3      80.55
# 4     147.06
# 5     -73.41

# %%
city_weather.agg(['count', 'mean', 'std','min','max'])
# Out:
#            City  Cloudiness (%) Country                           Date  \
# count       534      534.000000     534                            534
# min     abasolo        0.000000      AE  1970-01-01 00:00:01.603341644
# max    zyryanka      100.000000      ZM  1970-01-01 00:00:01.603342371
# mean        NaN       53.485019     NaN  1970-01-01 00:00:01.603342022
# std         NaN       38.544713     NaN                            NaN
#
#        Humidity (%)         Lat         Lng  Max Temp (F)  Windspeed (MPH)  \
# count    534.000000  534.000000  534.000000    534.000000       534.000000
# min       10.000000  -54.800000 -179.170000      6.640000         0.490000
# max      100.000000   78.220000  179.320000    100.400000        39.860000
# mean      74.462547   19.646367   18.008652     60.369082         7.945974
# std       20.133455   33.723423   90.754830     20.991569         5.390377
#
#          Latitude   Longitude
# count  534.000000  534.000000
# min    -54.800000 -179.170000
# max     78.220000  179.320000
# mean    19.646367   18.008652
# std     33.723423   90.754830

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_weather = city_weather[~(city_weather['Humidity (%)'] > 100)]
city_weather
city_weather['Humidity (%)'].max()
# Out:
# 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = round(city_weather,2)
clean_city_data.head()
# Out:
#           City Cloudiness (%) Country                          Date  \
# 0       atuona              3      PF 1970-01-01 00:00:01.603342249
# 1        ndele             94      CF 1970-01-01 00:00:01.603341837
# 3       dikson             99      RU 1970-01-01 00:00:01.603342265
# 4  new norfolk             75      AU 1970-01-01 00:00:01.603342265
# 5       bethel             90      US 1970-01-01 00:00:01.603342265
#
#   Humidity (%)    Lat     Lng  Max Temp (F) Windspeed (MPH)  Latitude  \
# 0           74   -9.8 -139.03         77.92           15.55     -9.80
# 1           81   8.41   20.65         70.20            2.89      8.41
# 3           96  73.51   80.55         25.50           11.99     73.51
# 4           59 -42.78  147.06         61.00            9.17    -42.78
# 5          100  41.37  -73.41         64.99            2.95     41.37
#
#    Longitude
# 0    -139.03
# 1      20.65
# 3      80.55
# 4     147.06
# 5     -73.41

# %%
today  = pd.Timestamp("today").strftime("%m/%d/%Y")
today
# Out:
# '10/21/2020'

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp (F)"], marker="o",color ='steelblue', edgecolor='black')

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Temperature as of {today}')
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

#Analysis
print("The data appears to suggest that max temperature gets greater as the latitiude get closer to zero (the equator)")
# Out:
# The data appears to suggest that max temperature gets greater as the latitiude get closer to zero (the equator)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity (%)"], marker="o", color ='steelblue', edgecolor='black')

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Humidity as of {today}')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

#Analysis
print("The data appears to show no real relationship between latitude and humidity. An inference can be made that there are more cities in the dataset with high humidity than low humidity.")
# Out:
# The data appears to show no real relationship between latitude and humidity. An inference can be made that there are more cities in the dataset with high humidity than low humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness (%)"], marker="o",color ='steelblue', edgecolor='black')

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Cloudiness as of {today}')
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

#Analysis
print("The data appears to show no real relationship between cloudiness and latitude.")
# Out:
# The data appears to show no real relationship between cloudiness and latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(clean_city_data["Lat"], clean_city_data["Windspeed (MPH)"], marker="o",color ='steelblue', edgecolor='black')

# Incorporate the other graph properties
plt.title(f'City Latitude vs. Windspeed as of {today}')
plt.ylabel("Windspeed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

#Analysis
print("The data appears to show no real relationship between windspeed and latitude. It appears that it was not very windy at the time the data was pulled worldwide.")
# Out:
# The data appears to show no real relationship between windspeed and latitude. It appears that it was not very windy at the time the data was pulled worldwide.

# %% [markdown]
# ## Linear Regression

# %%
north_df = clean_city_data.loc[pd.to_numeric(clean_city_data['Lat']).astype(float) > 0,:]
south_df = clean_city_data.loc[pd.to_numeric(clean_city_data['Lat']).astype(float) < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north_df['Lat']).astype(float)
y_values = pd.to_numeric(north_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.97x + 92.99
# The r-squared is: -0.9080200469602953
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_df['Lat']).astype(float)
y_values = pd.to_numeric(south_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the southern hemisphere, as you move closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.57x + 83.52
# The r-squared is: 0.6259056301642685
# The regression displays a negative correlation.
# In the southern hemisphere, as you move closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north_df['Lat']).astype(float)
y_values = pd.to_numeric(north_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('Northern Hemisphere - Humidity % vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display and correlation.")
plt.show()
# Out:
# Regression line equation is: y = 0.27x + 65.69
# The r-squared is: 0.2699700720347976
# The regression does not display and correlation.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_df['Lat']).astype(float)
y_values = pd.to_numeric(south_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('Southern Hemisphere - Humidity % vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display and correlation.")
plt.show()
# Out:
# Regression line equation is: y = 0.21x + 74.6
# The r-squared is: 0.14774839134434287
# The regression does not display and correlation.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north_df['Lat']).astype(float)
y_values = pd.to_numeric(north_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.title('Northern Hemisphere - Cloudiness % vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display and correlation.")
plt.show()
# Out:
# Regression line equation is: y = 0.41x + 37.63
# The r-squared is: 0.20707454373624534
# The regression does not display and correlation.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_df['Lat']).astype(float)
y_values = pd.to_numeric(south_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.title('southern Hemisphere - Cloudiness % vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display and correlation.")
plt.show()
# Out:
# Regression line equation is: y = 0.15x + 55.73
# The r-squared is: 0.055710500269639744
# The regression does not display and correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north_df['Lat']).astype(float)
y_values = pd.to_numeric(north_df['Windspeed (MPH)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(25,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display and correlation.")
plt.show()
# Out:
# Regression line equation is: y = 0.02x + 6.61
# The r-squared is: 0.09773090135086163
# The regression does not display and correlation.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south_df['Lat']).astype(float)
y_values = pd.to_numeric(south_df['Windspeed (MPH)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display and correlation.")
plt.show()
# Out:
# Regression line equation is: y = -0.06x + 7.45
# The r-squared is: -0.13820794401588885
# The regression does not display and correlation.
